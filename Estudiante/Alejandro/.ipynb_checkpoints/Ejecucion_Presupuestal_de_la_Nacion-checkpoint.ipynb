# %% [markdown]
# # EJECUCIÓN PRESUPUESTAL DE LA NACIÓN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %% [markdown]
# ## 1. Leer Información

# %%
archivo = input("Ingrese nombre del archivo: ")
data = pd.read_csv(archivo+".csv")
data.head()
# Out:
# Ingrese nombre del archivo: 2019
#                                        NombreEntidad  \
# 0  CORPOAMAZONIA - CORPORACION PARA EL DESARROLLO...
# 1  SECRETARIA DISTRITAL DE SEGURIDAD  CONVIVENCIA...
# 2                      ALCALDIA MUNICIPAL FUSAGASUGA
# 3  INSTITUTO DISTRITAL DE LA PARTICIPACION Y ACCI...
# 4  COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE ...
#
#                  Departamento       Ciudad                             Sector  \
# 0                    Putumayo        Mocoa   Ambiente y Desarrollo Sostenible
# 1  Distrito Capital de Bogota  No Definido             No aplica/No pertenece
# 2                Cundinamarca   Fusagasuga             No aplica/No pertenece
# 3  Distrito Capital de Bogota  No Definido  Inclusion Social y Reconciliacion
# 4                      Tolima       Ibague                    Ley de Justicia
#
#                    Rama    DestinoGasto EstadoContrato  \
# 0  Corporacion Autonoma       Inversion         Activo
# 1             Ejecutivo       Inversion     Modificado
# 2             Ejecutivo       Inversion         Activo
# 3             Ejecutivo       Inversion     Modificado
# 4             Ejecutivo  Funcionamiento         Activo
#
#                                DescripciondelProceso           TipodeContrato  \
# 0  Prestar sus servicios profesionales a la Entid...  Prestacion de servicios
# 1  PRESTAR LOS SERVICIOS PROFESIONALES EN DERECHO...  Prestacion de servicios
# 2  SERVICIOS PROFESIONALES PARA EL FORTALECIMIENT...  Prestacion de servicios
# 3  Prestar los servicios profesionales  con auton...  Prestacion de servicios
# 4  FIN CONTRATAR LA ADQUISICION DE ELEMENTOS DE O...              Compraventa
#
#   ModalidaddeContratacion  ... FechadeFindelContrato      TipoDocProveedor  \
# 0    Contratacion directa  ...            2019-08-20  Cedula de Ciudadania
# 1    Contratacion directa  ...            2020-04-30  Cedula de Ciudadania
# 2    Contratacion directa  ...            2019-12-27  Cedula de Ciudadania
# 3    Contratacion directa  ...            2019-12-31  Cedula de Ciudadania
# 4          Minima cuantia  ...            2019-07-30                   NIT
#
#                 ProveedorAdjudicado EsGrupo EsPyme  ValordelContrato  \
# 0    Karen Dayana Montenegro Chiran   False  False            12.250
# 1       YENNY PAOLIN DAZA GUTIERREZ   False  False            63.963
# 2  Sandra milena Gutierrez Castanho   False   True            30.723
# 3   ANGELA LUCIA HERNANDEZ PINHEROS   False  False            57.200
# 4     DISTRIBUCIONES ALIADAS BJ SAS   False   True            24.000
#
#    ValorPendientedePago  ValorPagado  DiasAdicionados    Anho
# 0                12.250          0.0              0.0  2019.0
# 1                63.963          0.0             91.0  2019.0
# 2                30.723          0.0              0.0  2019.0
# 3                 0.000         57.2             15.0  2019.0
# 4                24.000          0.0              0.0  2019.0
#
# [5 rows x 22 columns]

# %%
data.shape
# Out:
# (139028, 22)

# %%
column_data = data.columns.values.tolist()
column_data
# Out:
# ['NombreEntidad',
#  'Departamento',
#  'Ciudad',
#  'Sector',
#  'Rama',
#  'DestinoGasto',
#  'EstadoContrato',
#  'DescripciondelProceso',
#  'TipodeContrato',
#  'ModalidaddeContratacion',
#  'FechadeFirma',
#  'FechadeIniciodelContrato',
#  'FechadeFindelContrato',
#  'TipoDocProveedor',
#  'ProveedorAdjudicado',
#  'EsGrupo',
#  'EsPyme',
#  'ValordelContrato',
#  'ValorPendientedePago',
#  'ValorPagado',
#  'DiasAdicionados',
#  'Anho']

# %%
data.describe()
# Out:
#        ValordelContrato  ValorPendientedePago    ValorPagado  DiasAdicionados  \
# count     139028.000000         139028.000000  139028.000000    139028.000000
# mean         182.015682            171.050030      23.006744         1.273283
# std         3612.533321           3839.299928     415.357936        13.035735
# min            0.000000            -47.780039       0.000000         0.000000
# 25%           13.651000              4.326000       0.000000         0.000000
# 50%           27.792434             17.950925       0.000000         0.000000
# 75%           55.000000             43.142867       4.000000         0.000000
# max       685636.968401         685636.968401   58180.334144      1096.000000
#
#            Anho
# count  139028.0
# mean     2019.0
# std         0.0
# min      2019.0
# 25%      2019.0
# 50%      2019.0
# 75%      2019.0
# max      2019.0

# %%
data.NombreEntidad.unique()
# Out:
# array(['CORPOAMAZONIA - CORPORACION PARA EL DESARROLLO SOSTENIBLE DEL SUR DE LA AMAZONIA',
#        'SECRETARIA DISTRITAL DE SEGURIDAD  CONVIVENCIA Y JUSTICIA',
#        'ALCALDIA MUNICIPAL FUSAGASUGA', ...,
#        'ESTABLECIMIENTO PENITENCIARIO Y CARCELARIO SAN ANDRES INPEC',
#        'ICBF REGIONAL CESAR', 'ALCALDIA MUNICIPIO PAIME'], dtype=object)

# %%
data.Departamento.unique()
# Out:
# array(['Putumayo', 'Distrito Capital de Bogota', 'Cundinamarca', 'Tolima',
#        'Valle del Cauca', 'Casanare', 'Risaralda', 'Meta', 'Antioquia',
#        'Caqueta', 'Santander', 'Atlantico', 'Norte de Santander',
#        'Bolivar', 'Caldas', 'Huila', 'La Guajira', 'Vichada', 'Boyaca',
#        'Cesar', 'No Definido', 'San Andres, Providencia y Santa Catalina',
#        'Cauca', 'Guaviare', 'Narinho', 'Cordoba', 'Amazonas', 'Quindio',
#        'Magdalena', 'Sucre', 'Guainia', 'Arauca', 'Choco', 'Vaupes'],
#       dtype=object)

# %%
data.Sector.unique()
# Out:
# array(['Ambiente y Desarrollo Sostenible', 'No aplica/No pertenece',
#        'Inclusion Social y Reconciliacion', 'Ley de Justicia',
#        'Hacienda y Credito Publico', 'Salud y Proteccion Social',
#        'Planeacion', 'Cultura', 'defensa', 'deportes',
#        'Educacion Nacional', 'Servicio Publico', 'interior', 'Trabajo',
#        'Transporte', 'agricultura', 'Vivienda, Ciudad y Territorio',
#        'Minas y Energia', 'Informacion Estadistica', 'Ciencia Tecnologia',
#        'Presidencia de la Republica', 'Industria',
#        'Tecnologias de la Informacion y las Comunicaciones',
#        'Relaciones Exteriores',
#        'Inteligencia Estrategica y Contrainteligencia'], dtype=object)

# %%
data.Rama.unique()
# Out:
# array(['Corporacion Autonoma', 'Ejecutivo', 'Judicial', 'Legislativo'],
#       dtype=object)

# %%
data.DestinoGasto.unique()
# Out:
# array(['Inversion', 'Funcionamiento', 'No Definido'], dtype=object)

# %%
data.Anho.unique()
# Out:
# array([2019.])

# %% [markdown]
# ## 2. Consultar los Contratos más Costosos y la Deuda por Departamento

# %% [markdown]
# ### Requerimiento 1 : Contratos más Costosos

# %%
#df_contrato_costoso = data[data]
df_contrato_costoso=data.sort_values("ValordelContrato").tail(10)
df_contrato_costoso=df_contrato_costoso.loc[:,["NombreEntidad",
                                               "Departamento",
                                               "ProveedorAdjudicado",
                                               "ValordelContrato"]]
df_contrato_costoso
# Out:
#                                             NombreEntidad  \
# 114400  UNIDAD DE SERVICIOS PENITENCIARIOS Y CARCELARI...
# 128943             MINISTERIO DE EDUCACION NACIONAL (MEN)
# 15225                      INSTITUTO DE DESARROLLO URBANO
# 58177                DIRECCION GENERAL DE SANIDAD MILITAR
# 87705   SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...
# 119725                         DISPENSARIO MEDICO DE CALI
# 71580   FONDO ROTATORIO DEL MINISTERIO DE RELACIONES E...
# 42390   INSTITUTO DISTRITAL DE DEPORTE Y RECREACION DE...
# 18103   EMPRESA DE TRANSPORTE DEL TERCER MILENIO TRANS...
# 124462          SENA DIRECCION GENERAL Direccion Juridica
#
#                       Departamento  \
# 114400  Distrito Capital de Bogota
# 128943  Distrito Capital de Bogota
# 15225   Distrito Capital de Bogota
# 58177   Distrito Capital de Bogota
# 87705   Distrito Capital de Bogota
# 119725             Valle del Cauca
# 71580   Distrito Capital de Bogota
# 42390                      Bolivar
# 18103   Distrito Capital de Bogota
# 124462  Distrito Capital de Bogota
#
#                                       ProveedorAdjudicado  ValordelContrato
# 114400                           CONSORCIO FUNDACION 2020     183630.270298
# 128943  INSTITUTO COLOMBIANO DE CREDITO EDUCATIVO Y ES...     248453.357124
# 15225                               CONSORCIO CARACAS SUR     256554.412806
# 58177                            HOSPITAL MILITAR CENTRAL     271556.235168
# 87705                        Brigitte Lorena Rincon Bello     310120.202359
# 119725                                          UT FABILU     323783.467000
# 71580                                 UT PASAPORTES 2.019     332018.554517
# 42390                         FUNDACION GOLES POR LA VIDA     359800.000000
# 18103                                MASIVO BOGOTA S.A.S.     503262.600000
# 124462               Colombia Telecomunicaciones S.A. ESP     685636.968401

# %% [markdown]
# ### Requerimiento 2 : Deuda por Departamento

# %%
df_deuda_dpto=data.groupby("Departamento")["ValorPendientedePago"].sum()
df_deuda_dpto=df_deuda_dpto.sort_values().tail(10)
df_deuda_dpto.plot(kind="barh")
plt.xlabel("Valor Pendiente de Pago")
plt.title("Departamento más Deudores")
plt.show()

# %% [markdown]
# ## 3. Estudiar los Valores de los Contratos por Rama del estado

# %% [markdown]
# ### Requerimiento 3: Valor total de los contratos por cada rama

# %%
lim_inferior=float(input("Ingrese el valor en pesos del limite inferior: "))
lim_superior=float(input("Ingrese el valor en pesos del limite superior: "))
# Out:
# Ingrese el valor en pesos del limite inferior: 1
# Ingrese el valor en pesos del limite superior: 10

# %%
df_rama = data[(data["ValordelContrato"] >= lim_inferior) & (data["ValordelContrato"] <= lim_superior)]
df_rama.head(5)
# Out:
#                                         NombreEntidad  \
# 5   MUNICIPIO DE SANTIAGO DE CALI - DEPARTAMENTO A...
# 11  ESTABLECIMIENTO PENITENCIARIO DE MEDIANA SEGUR...
# 13              INPEC-RECLUSION DE MUJERES DE PEREIRA
# 16   SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR E.S.E
# 24  SECRETARIA DE DEPORTE Y RECREACION DE SANTIAGO...
#
#                   Departamento        Ciudad                      Sector  \
# 5              Valle del Cauca          Cali  Hacienda y Credito Publico
# 11                Cundinamarca    Fusagasuga             Ley de Justicia
# 13                   Risaralda  Dosquebradas             Ley de Justicia
# 16  Distrito Capital de Bogota        Bogota   Salud y Proteccion Social
# 24             Valle del Cauca          Cali                    deportes
#
#                     Rama    DestinoGasto EstadoContrato  \
# 5   Corporacion Autonoma  Funcionamiento         Activo
# 11             Ejecutivo  Funcionamiento        Cerrado
# 13             Ejecutivo  Funcionamiento      terminado
# 16             Ejecutivo  Funcionamiento     Modificado
# 24             Ejecutivo       Inversion     Modificado
#
#                                 DescripciondelProceso  \
# 5   Prestar los servicios Profesionales como Aboga...
# 11  CONTRATAR ADQUISICION MATERIAL PARA EL FUNCION...
# 13  CONCENTRADO (ALIMENTO)  MATERIAL VETERINARIO Y...
# 16  PRESTAR SERVICIOS DE APOYO A LA GESTION ASISTE...
# 24  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
#
#              TipodeContrato        ModalidaddeContratacion  ...  \
# 5   Prestacion de servicios           Contratacion directa  ...
# 11              Suministros                 Minima cuantia  ...
# 13              Compraventa                 Minima cuantia  ...
# 16        DecreeLaw092/2017  Contratacion regimen especial  ...
# 24  Prestacion de servicios           Contratacion directa  ...
#
#    FechadeFindelContrato      TipoDocProveedor            ProveedorAdjudicado  \
# 5             2019-05-01  Cedula de Ciudadania  Jaime Alberto Restrepo Garcia
# 11            2019-10-30                   NIT            L&S INVERSIONES SAS
# 13            2019-05-18  Cedula de Ciudadania    Vivian Mejia o Agroanimales
# 16            2019-09-30  Cedula de Ciudadania  carlos mario martinez alvarez
# 24            2019-06-01  Cedula de Ciudadania    ALAN JIMENO PAZ RIVADENEIRA
#
#    EsGrupo EsPyme  ValordelContrato  ValorPendientedePago  ValorPagado  \
# 5    False  False         10.000000             10.000000          0.0
# 11   False   True          7.449903              7.449903          0.0
# 13   False   True          4.459925              4.459925          0.0
# 16   False   True          9.528960              9.528960          0.0
# 24   False  False          4.140000              4.140000          0.0
#
#     DiasAdicionados    Anho
# 5               0.0  2019.0
# 11              0.0  2019.0
# 13              0.0  2019.0
# 16              0.0  2019.0
# 24              0.0  2019.0
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Rama",y="ValordelContrato",data=df_rama)
plt.ylabel("Valor del Contrato")
plt.xlabel("Rama Contratadora")
plt.title("Valor de Contratos por Rama")
plt.show()

# %% [markdown]
# ### Requerimiento 4: Repartición Porcentual del Valor Total de los Contratos entre las Diferentes Ramas del estado

# %%
data.groupby("Rama")["ValordelContrato"].sum().plot(kind="pie",
                                                   autopct="%0.1f %%")
plt.ylabel("Valor del Contrato")
plt.axis("equal")
plt.title("Distribución de Valor de Contratos por Rama")
plt.show()

# %% [markdown]
# ### Requerimiento 5: Distribución de los Valores de los Contratos
#
# * KDE -> Kernel Density Estimation

# %%
data_100 = data[data.ValordelContrato<100]
sns.kdeplot(data_100.ValordelContrato,shade=True)
plt.xlim((0,100))
plt.title("Distribución de los Valores de los Contratos")
plt.xlabel("Valor Contrato")
plt.ylabel("Densidad de Probabilidad")
plt.show()

# %% [markdown]
# ## 4. Estudiar los Valores de los Contratos por Sector y Departamento
#
# ### Requerimiento 6: Construcción de la Matriz de Departamentos VS Sectores

# %%
data_filter = data[data.Departamento != "No Definido"]
new_data = data_filter.loc[:,["Departamento","Sector","ValordelContrato"]]
new_data = new_data.groupby(["Departamento","Sector"]).sum()
new_data=new_data.pivot_table("ValordelContrato",index="Departamento",columns="Sector")
new_data=new_data.fillna(0)
new_data
# Out:
# Sector                                    Ambiente y Desarrollo Sostenible  \
# Departamento
# Amazonas                                                          0.000000
# Antioquia                                                     52939.180109
# Arauca                                                            0.000000
# Atlantico                                                         0.000000
# Bolivar                                                        1946.133880
# Boyaca                                                         4796.710681
# Caldas                                                         7263.758326
# Caqueta                                                           0.000000
# Casanare                                                       4934.973740
# Cauca                                                           434.609545
# Cesar                                                             0.000000
# Choco                                                             0.000000
# Cordoba                                                           0.000000
# Cundinamarca                                                   4789.108979
# Distrito Capital de Bogota                                   304527.855433
# Guainia                                                           0.000000
# Guaviare                                                          0.000000
# Huila                                                           123.583531
# La Guajira                                                        0.000000
# Magdalena                                                     44931.689761
# Meta                                                           7024.008660
# Narinho                                                         623.106034
# Norte de Santander                                                0.000000
# Putumayo                                                      10527.101652
# Quindio                                                         743.975035
# Risaralda                                                     12610.933509
# San Andres, Providencia y Santa Catalina                          0.000000
# Santander                                                     26478.903065
# Sucre                                                             0.000000
# Tolima                                                        24409.573436
# Valle del Cauca                                               14013.133674
# Vaupes                                                            0.000000
# Vichada                                                           0.000000
#
# Sector                                    Ciencia Tecnologia        Cultura  \
# Departamento
# Amazonas                                            0.000000       0.000000
# Antioquia                                           0.000000    1729.000000
# Arauca                                              0.000000       0.000000
# Atlantico                                           0.000000       0.000000
# Bolivar                                             0.000000     164.163000
# Boyaca                                              0.000000     568.434334
# Caldas                                              0.000000       0.000000
# Caqueta                                             0.000000       0.000000
# Casanare                                            0.000000       0.000000
# Cauca                                               0.000000       0.000000
# Cesar                                               0.000000       0.000000
# Choco                                               0.000000       0.000000
# Cordoba                                             0.000000       0.000000
# Cundinamarca                                        0.000000       0.000000
# Distrito Capital de Bogota                      28007.232309  634313.744940
# Guainia                                             0.000000       0.000000
# Guaviare                                            0.000000       0.000000
# Huila                                               0.000000    1262.911440
# La Guajira                                          0.000000       0.000000
# Magdalena                                           0.000000       0.000000
# Meta                                                0.000000       0.000000
# Narinho                                             0.000000       0.000000
# Norte de Santander                                  0.000000       0.000000
# Putumayo                                            0.000000       0.000000
# Quindio                                             0.000000       0.000000
# Risaralda                                           0.000000       0.000000
# San Andres, Providencia y Santa Catalina            0.000000       0.000000
# Santander                                           0.000000   23704.508429
# Sucre                                               0.000000       0.000000
# Tolima                                              0.000000       0.000000
# Valle del Cauca                                     0.000000   21549.433167
# Vaupes                                              0.000000       0.000000
# Vichada                                             0.000000       0.000000
#
# Sector                                    Educacion Nacional  \
# Departamento
# Amazonas                                        0.000000e+00
# Antioquia                                       2.441300e+03
# Arauca                                          0.000000e+00
# Atlantico                                       1.113372e+03
# Bolivar                                         7.457484e+02
# Boyaca                                          8.988234e+02
# Caldas                                          0.000000e+00
# Caqueta                                         0.000000e+00
# Casanare                                        0.000000e+00
# Cauca                                           5.824428e+02
# Cesar                                           0.000000e+00
# Choco                                           0.000000e+00
# Cordoba                                         0.000000e+00
# Cundinamarca                                    3.506737e+04
# Distrito Capital de Bogota                      1.359093e+06
# Guainia                                         0.000000e+00
# Guaviare                                        0.000000e+00
# Huila                                           1.263884e+03
# La Guajira                                      0.000000e+00
# Magdalena                                       0.000000e+00
# Meta                                            8.346298e+02
# Narinho                                         7.247313e+02
# Norte de Santander                              6.677252e+02
# Putumayo                                        0.000000e+00
# Quindio                                         0.000000e+00
# Risaralda                                       4.657294e+02
# San Andres, Providencia y Santa Catalina        2.336875e+03
# Santander                                       6.375716e+02
# Sucre                                           1.640883e+01
# Tolima                                          4.041832e+03
# Valle del Cauca                                 1.671774e+04
# Vaupes                                          0.000000e+00
# Vichada                                         0.000000e+00
#
# Sector                                    Hacienda y Credito Publico  \
# Departamento
# Amazonas                                                    0.000000
# Antioquia                                                   0.000000
# Arauca                                                      0.000000
# Atlantico                                                   0.000000
# Bolivar                                                     0.000000
# Boyaca                                                   1014.458970
# Caldas                                                      0.000000
# Caqueta                                                     0.000000
# Casanare                                                    0.000000
# Cauca                                                       0.000000
# Cesar                                                       0.000000
# Choco                                                       0.000000
# Cordoba                                                     0.000000
# Cundinamarca                                             4132.879257
# Distrito Capital de Bogota                             626994.160673
# Guainia                                                     0.000000
# Guaviare                                                    0.000000
# Huila                                                       0.000000
# La Guajira                                                  0.000000
# Magdalena                                                   0.000000
# Meta                                                        0.000000
# Narinho                                                     0.000000
# Norte de Santander                                          0.000000
# Putumayo                                                    0.000000
# Quindio                                                     0.000000
# Risaralda                                                   0.000000
# San Andres, Providencia y Santa Catalina                    0.000000
# Santander                                                   0.000000
# Sucre                                                       0.000000
# Tolima                                                      0.000000
# Valle del Cauca                                         11417.975640
# Vaupes                                                      0.000000
# Vichada                                                     0.000000
#
# Sector                                    Inclusion Social y Reconciliacion  \
# Departamento
# Amazonas                                                       0.000000e+00
# Antioquia                                                      0.000000e+00
# Arauca                                                         0.000000e+00
# Atlantico                                                      0.000000e+00
# Bolivar                                                        0.000000e+00
# Boyaca                                                         0.000000e+00
# Caldas                                                         0.000000e+00
# Caqueta                                                        0.000000e+00
# Casanare                                                       0.000000e+00
# Cauca                                                          0.000000e+00
# Cesar                                                          0.000000e+00
# Choco                                                          0.000000e+00
# Cordoba                                                        0.000000e+00
# Cundinamarca                                                   1.337891e+03
# Distrito Capital de Bogota                                     1.129529e+06
# Guainia                                                        0.000000e+00
# Guaviare                                                       0.000000e+00
# Huila                                                          0.000000e+00
# La Guajira                                                     0.000000e+00
# Magdalena                                                      0.000000e+00
# Meta                                                           0.000000e+00
# Narinho                                                        0.000000e+00
# Norte de Santander                                             0.000000e+00
# Putumayo                                                       0.000000e+00
# Quindio                                                        0.000000e+00
# Risaralda                                                      0.000000e+00
# San Andres, Providencia y Santa Catalina                       0.000000e+00
# Santander                                                      0.000000e+00
# Sucre                                                          0.000000e+00
# Tolima                                                         0.000000e+00
# Valle del Cauca                                                4.385825e+04
# Vaupes                                                         0.000000e+00
# Vichada                                                        0.000000e+00
#
# Sector                                        Industria  \
# Departamento
# Amazonas                                       0.000000
# Antioquia                                      0.000000
# Arauca                                         0.000000
# Atlantico                                      0.000000
# Bolivar                                        0.000000
# Boyaca                                         0.000000
# Caldas                                         0.000000
# Caqueta                                        0.000000
# Casanare                                       0.000000
# Cauca                                          0.000000
# Cesar                                        132.895024
# Choco                                          0.000000
# Cordoba                                        0.000000
# Cundinamarca                                 195.059240
# Distrito Capital de Bogota                258826.820299
# Guainia                                        0.000000
# Guaviare                                       0.000000
# Huila                                          0.000000
# La Guajira                                     0.000000
# Magdalena                                      0.000000
# Meta                                           0.000000
# Narinho                                        0.000000
# Norte de Santander                             0.000000
# Putumayo                                       0.000000
# Quindio                                        0.000000
# Risaralda                                      0.000000
# San Andres, Providencia y Santa Catalina       0.000000
# Santander                                      0.000000
# Sucre                                          0.000000
# Tolima                                       599.066380
# Valle del Cauca                             2330.414464
# Vaupes                                         0.000000
# Vichada                                        0.000000
#
# Sector                                    Informacion Estadistica  \
# Departamento
# Amazonas                                                 0.000000
# Antioquia                                             2545.285753
# Arauca                                                   0.000000
# Atlantico                                             3501.432658
# Bolivar                                                  0.000000
# Boyaca                                                   0.000000
# Caldas                                                  22.991875
# Caqueta                                                  0.000000
# Casanare                                                 0.000000
# Cauca                                                    0.000000
# Cesar                                                  159.105916
# Choco                                                    0.000000
# Cordoba                                                  0.000000
# Cundinamarca                                             0.000000
# Distrito Capital de Bogota                           82993.329247
# Guainia                                                  0.000000
# Guaviare                                                 0.000000
# Huila                                                    0.000000
# La Guajira                                               0.000000
# Magdalena                                                0.000000
# Meta                                                     0.000000
# Narinho                                                  0.000000
# Norte de Santander                                       0.000000
# Putumayo                                                 0.000000
# Quindio                                                  0.000000
# Risaralda                                                0.000000
# San Andres, Providencia y Santa Catalina                 0.000000
# Santander                                             1726.187626
# Sucre                                                    0.000000
# Tolima                                                   0.000000
# Valle del Cauca                                       2984.331354
# Vaupes                                                   0.000000
# Vichada                                                  0.000000
#
# Sector                                    Ley de Justicia  Minas y Energia  \
# Departamento
# Amazonas                                        36.513254         0.000000
# Antioquia                                    27921.014011         0.000000
# Arauca                                         315.622654         0.000000
# Atlantico                                     7715.688139         0.000000
# Bolivar                                       6506.424168         0.000000
# Boyaca                                       11415.528798         0.000000
# Caldas                                        7631.991255         0.000000
# Caqueta                                       1526.890563         0.000000
# Casanare                                      1558.592597         0.000000
# Cauca                                         8561.055650         0.000000
# Cesar                                         9550.993992         0.000000
# Choco                                           48.547139         6.300000
# Cordoba                                       1279.011057         0.000000
# Cundinamarca                                  5463.202520         0.000000
# Distrito Capital de Bogota                  771661.387045    300262.607872
# Guainia                                          0.000000         0.000000
# Guaviare                                         0.000000         0.000000
# Huila                                        11432.853563         0.000000
# La Guajira                                     334.721118         0.000000
# Magdalena                                     8542.107359         0.000000
# Meta                                         12441.710575         0.000000
# Narinho                                       8546.729954         0.000000
# Norte de Santander                           14305.702279         0.000000
# Putumayo                                         0.000000         0.000000
# Quindio                                       3149.414726         0.000000
# Risaralda                                     9262.577205         0.000000
# San Andres, Providencia y Santa Catalina         4.000000         0.000000
# Santander                                    15390.502410         0.000000
# Sucre                                         6533.635478         0.000000
# Tolima                                       11524.565136         0.000000
# Valle del Cauca                              22744.805245         0.000000
# Vaupes                                           0.000000         0.000000
# Vichada                                          0.000000         0.000000
#
# Sector                                    ...  Salud y Proteccion Social  \
# Departamento                              ...
# Amazonas                                  ...               0.000000e+00
# Antioquia                                 ...               4.108356e+04
# Arauca                                    ...               4.579839e+03
# Atlantico                                 ...               1.845972e+04
# Bolivar                                   ...               1.045117e+05
# Boyaca                                    ...               4.607774e+03
# Caldas                                    ...               1.400816e+04
# Caqueta                                   ...               2.478019e+03
# Casanare                                  ...               6.226080e+03
# Cauca                                     ...               7.871597e+03
# Cesar                                     ...               2.016131e+01
# Choco                                     ...               3.150096e+03
# Cordoba                                   ...               4.937745e+03
# Cundinamarca                              ...               2.231813e+04
# Distrito Capital de Bogota                ...               1.402357e+06
# Guainia                                   ...               1.156824e+03
# Guaviare                                  ...               2.542101e+03
# Huila                                     ...               4.234502e+04
# La Guajira                                ...               0.000000e+00
# Magdalena                                 ...               5.861449e+03
# Meta                                      ...               3.272580e+03
# Narinho                                   ...               2.765124e+02
# Norte de Santander                        ...               4.147930e+03
# Putumayo                                  ...               5.037354e+03
# Quindio                                   ...               3.685245e+03
# Risaralda                                 ...               2.400000e+00
# San Andres, Providencia y Santa Catalina  ...               7.909365e+02
# Santander                                 ...               8.110953e+03
# Sucre                                     ...               1.111361e+03
# Tolima                                    ...               2.983363e+04
# Valle del Cauca                           ...               3.651086e+05
# Vaupes                                    ...               2.837411e+03
# Vichada                                   ...               1.302838e+03
#
# Sector                                    Servicio Publico  \
# Departamento
# Amazonas                                      0.000000e+00
# Antioquia                                     6.592706e+05
# Arauca                                        5.123778e+01
# Atlantico                                     3.185681e+04
# Bolivar                                       7.709883e+03
# Boyaca                                        2.655991e+04
# Caldas                                        4.061600e+03
# Caqueta                                       8.932965e+02
# Casanare                                      5.217663e+02
# Cauca                                         2.498400e+02
# Cesar                                         1.445563e+03
# Choco                                         0.000000e+00
# Cordoba                                       1.207756e+04
# Cundinamarca                                  2.397668e+04
# Distrito Capital de Bogota                    1.197264e+06
# Guainia                                       0.000000e+00
# Guaviare                                      2.708826e+02
# Huila                                         2.059709e+05
# La Guajira                                    6.700001e+02
# Magdalena                                     0.000000e+00
# Meta                                          0.000000e+00
# Narinho                                       1.868088e+03
# Norte de Santander                            5.433797e+02
# Putumayo                                      1.080000e+03
# Quindio                                       7.525228e+02
# Risaralda                                     1.121637e+04
# San Andres, Providencia y Santa Catalina      0.000000e+00
# Santander                                     8.416708e+04
# Sucre                                         3.076500e+02
# Tolima                                        1.098395e+05
# Valle del Cauca                               2.657255e+04
# Vaupes                                        0.000000e+00
# Vichada                                       3.717100e+01
#
# Sector                                    Tecnologias de la Informacion y las Comunicaciones  \
# Departamento
# Amazonas                                                                           0.000000
# Antioquia                                                                      20153.145561
# Arauca                                                                             0.000000
# Atlantico                                                                          0.000000
# Bolivar                                                                            0.000000
# Boyaca                                                                             0.000000
# Caldas                                                                             0.000000
# Caqueta                                                                            0.000000
# Casanare                                                                           0.000000
# Cauca                                                                              0.000000
# Cesar                                                                              0.000000
# Choco                                                                              0.000000
# Cordoba                                                                            0.000000
# Cundinamarca                                                                       0.000000
# Distrito Capital de Bogota                                                    783168.123873
# Guainia                                                                            0.000000
# Guaviare                                                                           0.000000
# Huila                                                                              0.000000
# La Guajira                                                                         0.000000
# Magdalena                                                                          0.000000
# Meta                                                                               0.000000
# Narinho                                                                            0.000000
# Norte de Santander                                                                 0.000000
# Putumayo                                                                           0.000000
# Quindio                                                                            0.000000
# Risaralda                                                                          0.000000
# San Andres, Providencia y Santa Catalina                                           0.000000
# Santander                                                                          0.000000
# Sucre                                                                              0.000000
# Tolima                                                                             0.000000
# Valle del Cauca                                                                 4337.760098
# Vaupes                                                                             0.000000
# Vichada                                                                            0.000000
#
# Sector                                          Trabajo    Transporte  \
# Departamento
# Amazonas                                       0.000000  0.000000e+00
# Antioquia                                   5191.326154  0.000000e+00
# Arauca                                         0.000000  0.000000e+00
# Atlantico                                    161.713548  1.149450e+02
# Bolivar                                       58.183799  2.623243e+02
# Boyaca                                      1064.292998  0.000000e+00
# Caldas                                        51.964084  0.000000e+00
# Caqueta                                       25.817201  0.000000e+00
# Casanare                                      35.913252  0.000000e+00
# Cauca                                         84.487100  0.000000e+00
# Cesar                                       1766.519273  0.000000e+00
# Choco                                         14.851992  0.000000e+00
# Cordoba                                        9.087300  0.000000e+00
# Cundinamarca                                  93.935177  0.000000e+00
# Distrito Capital de Bogota                990249.073571  3.528140e+06
# Guainia                                        0.000000  0.000000e+00
# Guaviare                                      29.705200  0.000000e+00
# Huila                                         61.251596  0.000000e+00
# La Guajira                                    18.324878  0.000000e+00
# Magdalena                                     49.987070  0.000000e+00
# Meta                                          63.402817  0.000000e+00
# Narinho                                       48.651927  0.000000e+00
# Norte de Santander                             6.345000  0.000000e+00
# Putumayo                                       0.000000  0.000000e+00
# Quindio                                       26.671582  0.000000e+00
# Risaralda                                     92.117582  0.000000e+00
# San Andres, Providencia y Santa Catalina       0.000000  0.000000e+00
# Santander                                  54548.878998  8.933174e+02
# Sucre                                         30.416150  0.000000e+00
# Tolima                                      1047.507294  0.000000e+00
# Valle del Cauca                             1427.745691  6.859360e+03
# Vaupes                                         0.000000  0.000000e+00
# Vichada                                        0.000000  0.000000e+00
#
# Sector                                    Vivienda, Ciudad y Territorio  \
# Departamento
# Amazonas                                                       0.000000
# Antioquia                                                    583.484285
# Arauca                                                         0.000000
# Atlantico                                                      0.000000
# Bolivar                                                        0.000000
# Boyaca                                                         0.000000
# Caldas                                                         0.000000
# Caqueta                                                     4816.823800
# Casanare                                                       0.000000
# Cauca                                                          1.996000
# Cesar                                                          0.000000
# Choco                                                          0.000000
# Cordoba                                                        0.000000
# Cundinamarca                                                1044.219674
# Distrito Capital de Bogota                                168836.222613
# Guainia                                                        0.000000
# Guaviare                                                       0.000000
# Huila                                                        684.647024
# La Guajira                                                     0.000000
# Magdalena                                                  69718.023844
# Meta                                                           0.000000
# Narinho                                                        0.000000
# Norte de Santander                                             0.000000
# Putumayo                                                       0.000000
# Quindio                                                        0.000000
# Risaralda                                                      0.000000
# San Andres, Providencia y Santa Catalina                       0.000000
# Santander                                                   2233.870218
# Sucre                                                          0.000000
# Tolima                                                      2212.082412
# Valle del Cauca                                             2381.549705
# Vaupes                                                         0.000000
# Vichada                                                        0.000000
#
# Sector                                      agricultura       defensa  \
# Departamento
# Amazonas                                       0.000000  5.028948e+03
# Antioquia                                      0.000000  6.261735e+04
# Arauca                                         0.000000  8.036832e+03
# Atlantico                                      0.000000  3.617590e+04
# Bolivar                                        0.000000  3.974907e+04
# Boyaca                                         0.000000  1.970833e+04
# Caldas                                         0.000000  1.477858e+04
# Caqueta                                        0.000000  2.289233e+04
# Casanare                                       0.000000  1.179081e+04
# Cauca                                          0.000000  1.145160e+04
# Cesar                                       1771.176821  1.462335e+04
# Choco                                          0.000000  7.067161e+03
# Cordoba                                        0.000000  2.658265e+04
# Cundinamarca                                   0.000000  9.308965e+04
# Distrito Capital de Bogota                291052.295545  3.393553e+06
# Guainia                                        0.000000  1.268294e+03
# Guaviare                                       0.000000  3.585653e+03
# Huila                                          0.000000  1.327840e+04
# La Guajira                                     0.000000  5.654164e+03
# Magdalena                                      0.000000  9.689105e+03
# Meta                                           0.000000  3.087469e+04
# Narinho                                        0.000000  2.246444e+04
# Norte de Santander                             0.000000  2.511351e+04
# Putumayo                                       0.000000  9.788674e+03
# Quindio                                        0.000000  1.401129e+04
# Risaralda                                      0.000000  1.163185e+04
# San Andres, Providencia y Santa Catalina       0.000000  8.107318e+03
# Santander                                    184.537191  4.940248e+04
# Sucre                                          0.000000  1.530942e+04
# Tolima                                         0.000000  1.983280e+04
# Valle del Cauca                                0.000000  7.826481e+04
# Vaupes                                         0.000000  0.000000e+00
# Vichada                                        0.000000  9.909245e+03
#
# Sector                                         deportes      interior
# Departamento
# Amazonas                                       0.000000      0.000000
# Antioquia                                   5371.210120     24.987008
# Arauca                                         0.000000      0.000000
# Atlantico                                      0.000000      0.000000
# Bolivar                                   381265.152258      0.000000
# Boyaca                                       514.205200      0.000000
# Caldas                                         0.000000      0.000000
# Caqueta                                        0.000000      0.000000
# Casanare                                     139.187000      0.000000
# Cauca                                          0.000000      0.000000
# Cesar                                          0.000000      0.000000
# Choco                                          0.000000      3.543600
# Cordoba                                        0.000000      0.000000
# Cundinamarca                                2285.749532    788.684025
# Distrito Capital de Bogota                 64485.152288  86764.241042
# Guainia                                        0.000000      0.000000
# Guaviare                                       0.000000      0.000000
# Huila                                          0.000000      0.000000
# La Guajira                                     0.000000      0.000000
# Magdalena                                   1638.165932      0.000000
# Meta                                           0.000000      0.000000
# Narinho                                        0.000000      0.000000
# Norte de Santander                             0.000000      0.000000
# Putumayo                                       0.000000      0.000000
# Quindio                                       97.424000      0.000000
# Risaralda                                      0.000000      0.000000
# San Andres, Providencia y Santa Catalina       0.000000      0.000000
# Santander                                   4315.569296      0.000000
# Sucre                                          0.000000      0.000000
# Tolima                                     59059.969592      0.000000
# Valle del Cauca                            77093.507588      0.000000
# Vaupes                                         0.000000      0.000000
# Vichada                                      148.051610      0.000000
#
# [33 rows x 24 columns]

# %% [markdown]
# ### Requerimiento 7: Sectores en los que el Estado Invierte más y menos, de acuerdo al valor de sus contratos

# %%
def Sectores_inversion(data:pd.DataFrame,info:int,):
    new_sector = data.columns.values.tolist()
    min_sector=[]
    if info == 0:
        minimo = [9999999,""]
        for i in new_sector:
            suma = new_data[i].sum()
            min_sector.append(suma)
            if suma < minimo[0]:
                minimo[0] = suma
                minimo[1] = i
        return (minimo[0],minimo[1])
    if info == 1:
        maximo = [0,""]
        for i in new_sector:
            suma = new_data[i].sum()
            min_sector.append(suma)
            if suma > maximo[0]:
                maximo[0] = suma
                maximo[1] = i
        return (maximo[0],maximo[1])

# %%
info =int(input('''Ingrese 0 para el sector de menor gasto y 1 para 
el de mayor gasto: '''))
Sectores_inversion(new_data,info)
# Out:
# Ingrese 0 para el sector de menor gasto y 1 para
# el de mayor gasto: 1
# (4095331.9601820093, 'defensa')

# %% [markdown]
# ### Requerimiento 8: Valor Total de los Contratos de un departamento

# %%
def valor_departamento(data:pd.DataFrame,departamento:str):
    data=data.reset_index(level=0)
    new_departamento = data.Departamento.unique().tolist()
    if departamento in new_departamento:
        valor=df[df.Departamento==departamento].sum(axis=1).tolist()
        return(departamento+": Valor Total -> "+str(valor))
    else:
        return ("Verifique que este bien escrito -> :(")

# %%
info_dep = input("Ingrese el Departamento: ")
valor_departamento(new_data,info_dep)
# Out:
# Ingrese el Departamento: Distrito Capital de Bogota
# 'Distrito Capital de Bogota: Valor Total -> [19789537.569170985]'

# %% [markdown]
# ### Requerimiento 9: con Mayor Gasto
